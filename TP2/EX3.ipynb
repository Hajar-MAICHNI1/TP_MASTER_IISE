# %% [markdown]
# # ***Série de Travaux Pratiques N° 2***

# %% [markdown]
#  **Exercice 3 :  Classe "CompteBancaire"**
# - Créez une classe "CompteBancaire" avec les attributs "titulaire" et "solde".
# - Ajoutez des méthodes pour :
#  - "deposer(montant)": pour ajouter de l'argent au solde.
#  - "retirer(montant)": pour retirer de l'argent du solde (vérifiez que le solde est suffisant).
#  - "afficher_solde()": pour afficher le solde actuel.
# - Créez un compte et testez les méthodes.

# %%
class CompteBancaire:
  def __init__(self,titulaire,solde):
    self.titulaire=titulaire
    self.solde=solde

  def deposer(self,montant):
    self.solde+=montant

  def retirer(self,montant):
    self.solde-=montant

  def afficher_solde(self):
    print(f"Le solde du compte bancaire de {self.titulaire} est de {self.solde} dirham.")

Compte=CompteBancaire("Med",1500)
Compte.deposer(120)
Compte.retirer(15)
Compte.afficher_solde()
# Out:
# Le solde du compte bancaire de Med est de 1605 dirham.
