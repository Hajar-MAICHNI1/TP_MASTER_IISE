# %% [markdown]
# # ***Série de Travaux Pratiques N° 2***

# %% [markdown]
# **Exercice 5 : Classe "Animal"**
# - Créez une classe "Animal" avec une méthode "faire_du_bruit". Créez des sous-classes "Chien" et
# "Chat", chacune avec sa propre implémentation de "faire_du_bruit".
# - Testez chaque sous-classe pour vérifier le bruit qu'elle fait.

# %%
class Animal:
  def faire_du_bruit(self):
    print("Le bruit de l'animal")

class Chien(Animal):
  def faire_du_bruit(self):
    print("Le chien aboie")

class Chat(Animal):
  def faire_du_bruit(self):
    print("Le chat miaule")

chien = Chien()
chat = Chat()

chien.faire_du_bruit()
chat.faire_du_bruit()
# Out:
# Le chien aboie
# Le chat miaule
